# %%
# Import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from selenium import webdriver
from datetime import datetime
import time
import os

from multiprocessing import current_process
from datetime import date, timedelta

# %% [markdown]
# ## Test Area

# %%
td = datetime.today().strftime('%m_%d_%Y'); path = "./" + td + "/"
os.system( "mkdir {}".format(td) )
yest = datetime.today() - timedelta(1)
yest = yest.strftime('%m_%d_%Y')

# %%
nba_stats_info = {"https://www.sportsbookreview.com/betting-odds/nba-basketball/money-line/": \
                  [["/html/body/div/div/div/div/section/div/div[3]/div[1]/div[1]/ol/li[1]", \
                    "/html/body/div/div/div/div/section/div/div[3]/div[1]/div[2]/ol/li[2]"],\
                  "bettingOddsGridContainer",\
                  [8,10] + [i for i in range(12,20)] + [23],\
                  ['%FGA','%3PA','%FTA','%OREB','%DREB','%REB','%AST','%TOV','%STL','%BLK','%PTS'],\
                  18,\
                  3,\
                   "/html/body/div/div/div/div/section/div/div[3]/div[2]/div[3]/div[3]/div[1]/div/div"]}

# %%
## Unpack data
url = "https://www.sportsbookreview.com/betting-odds/nba-basketball/money-line/"
#xpaths = nba_stats_info[url][0]
object_id = nba_stats_info[url][1]
#stats_args = nba_stats_info[url][2]
#cols = nba_stats_info[url][3]
#dp = nba_stats_info[url][4]
#fn = nba_stats_info[url][5]
#click_arrow = nba_stats_info[url][6]

# %%
## Set up chrome driver, open browser
path_to_chromedriver = "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/web_scraping/chromedriver"
browser = webdriver.Chrome(executable_path=path_to_chromedriver)
browser.get(url);
time.sleep(2)  ## make sure the browswer loads before executing xpaths

#cal = '/html/body/div/div/div/div/section/div/div[2]/div/div/span'
#day = '/html/body/div[5]/div/div/section/div/div/div[2]/div[2]/table/tbody/tr[5]/td[6]/div'
#browser.find_element_by_xpath(cal).click();
#time.sleep(2)
#browser.find_element_by_xpath(day).click();

# tr chunk represents rows (i.e. weeks of the month)
# td chunk represents days of week

# %%
## Use the xpaths to click the necessary browswer buttons
for xpath in xpaths:
    browser.find_element_by_xpath(xpath).click();
    time.sleep(2)  # Sleep in between

# %%
## Populate containers
table = browser.find_element_by_id(object_id)

# %%
# lists
teamNames = ['Phoenix','Orlando','Washington','Detroit','Indiana','Atlanta',
            'Toronto','Miami','Charlotte','Brooklyn','Cleveland','Memphis','Minnesota',
            'Chicago','New Orleans','Dallas','Denver','San Antonio','Sacramento','L.A. Clippers',
            'L.A. Lakers','Philadelphia','Boston', 'New York','Houston','Oklahoma City',
            'Golden State','Utah','Portland','Milwaukee']

# Containers
GameID = []
Date = []
Teams = []
Points = []
Wagers = []
Opener = []
Pinnacle = []
Fivedimes = []
Bookmaker = []
BetOnline = []

#Justbet = []
#Sportsbetting = []

#colnames = [GameID, Date, Teams, Points, Wagers, Pinnacle, Fivedimes, Bookmaker, BetOnline,
#           Bovada, Heritage, Intertops, Youwager, Justbet, Sportsbetting]

colnames = [GameID, Date, Teams, Points, Wagers, Opener, Pinnacle, Fivedimes, Bookmaker, BetOnline]

# %%
data = table.text.split("\n")[14:]
data
# Out:
# ['Time',
#  '|',
#  'TV',
#  'Rot',
#  'Fri Jan 25, 2019',
#  'WAGERS',
#  'OPENER',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '565',
#  'Washington',
#  '566',
#  'Orlando',
#  '24',
#  '21',
#  '26',
#  '17',
#  '25',
#  '31',
#  '20',
#  '22',
#  '95',
#  '91',
#  '53%',
#  '47%',
#  '+155',
#  '-175',
#  '+141',
#  '-156',
#  '+145',
#  '-155',
#  '+140',
#  '-160',
#  '+138',
#  '-158',
#  '07:30 PM',
#  'H2H',
#  '|',
#  '567',
#  'Miami',
#  '568',
#  'Cleveland',
#  '27',
#  '23',
#  '21',
#  '30',
#  '32',
#  '17',
#  '20',
#  '24',
#  '100',
#  '94',
#  '50%',
#  '50%',
#  '-400',
#  '+325',
#  '-385',
#  '+334',
#  '-385',
#  '+345',
#  '-400',
#  '+317',
#  '-400',
#  '+330',
#  '07:30 PM',
#  'H2H',
#  '|',
#  '569',
#  'New York',
#  '570',
#  'Brooklyn',
#  '37',
#  '30',
#  '23',
#  '30',
#  '22',
#  '27',
#  '17',
#  '22',
#  '99',
#  '109',
#  '52%',
#  '48%',
#  '+450',
#  '-600',
#  '+344',
#  '-398',
#  '+355',
#  '-400',
#  '+330',
#  '-420',
#  '+335',
#  '-405',
#  '08:00 PM',
#  'H2H',
#  '|',
#  '571',
#  'Toronto',
#  '572',
#  'Houston',
#  '20',
#  '33',
#  '41',
#  '37',
#  '28',
#  '26',
#  '30',
#  '25',
#  '119',
#  '121',
#  '51%',
#  '49%',
#  '-130',
#  '+100',
#  '-156',
#  '+141',
#  '-150',
#  '+140',
#  '-160',
#  '+140',
#  '-163',
#  '+143',
#  '08:00 PM',
#  'H2H',
#  '|',
#  '573',
#  'Sacramento',
#  '574',
#  'Memphis',
#  '24',
#  '23',
#  '24',
#  '19',
#  '29',
#  '29',
#  '22',
#  '25',
#  '99',
#  '96',
#  '52%',
#  '48%',
#  '+100',
#  '-130',
#  '+122',
#  '-135',
#  '+120',
#  '-130',
#  '+115',
#  '-135',
#  '+110',
#  '-130',
#  '08:00 PM',
#  'H2H',
#  '|',
#  '575',
#  'L.A. Clippers',
#  '576',
#  'Chicago',
#  '27',
#  '20',
#  '25',
#  '36',
#  '28',
#  '26',
#  '26',
#  '19',
#  '106',
#  '101',
#  '57%',
#  '43%',
#  '-4500',
#  '+1802',
#  '-191',
#  '+172',
#  '-190',
#  '+175',
#  '-210',
#  '+176',
#  '-205',
#  '+175',
#  '08:30 PM',
#  'H2H',
#  '|',
#  '577',
#  'Detroit',
#  '578',
#  'Dallas',
#  '28',
#  '23',
#  '26',
#  '39',
#  '31',
#  '26',
#  '16',
#  '18',
#  '101',
#  '106',
#  '48%',
#  '52%',
#  '+150',
#  '-180',
#  '+164',
#  '-182',
#  '+175',
#  '-190',
#  '+176',
#  '-210',
#  '+161',
#  '-181',
#  '08:30 PM',
#  'H2H',
#  '|',
#  '579',
#  'Charlotte',
#  '580',
#  'Milwaukee',
#  '27',
#  '22',
#  '27',
#  '30',
#  '33',
#  '24',
#  '12',
#  '32',
#  '99',
#  '108',
#  '44%',
#  '56%',
#  '+475',
#  '-650',
#  '+592',
#  '-733',
#  '+575',
#  '-710',
#  '+614',
#  '-900',
#  '+675',
#  '-900',
#  '09:00 PM',
#  'H2H',
#  '|',
#  '581',
#  'Phoenix',
#  '582',
#  'Denver',
#  '32',
#  '37',
#  '23',
#  '33',
#  '26',
#  '28',
#  '14',
#  '34',
#  '95',
#  '132',
#  '57%',
#  '43%',
#  '+800',
#  '-1475',
#  '+1087',
#  '-1571',
#  '+1150',
#  '-1450',
#  '+1098',
#  '-2200',
#  '+975',
#  '-1500',
#  '09:00 PM',
#  'H2H',
#  '|',
#  '583',
#  'Minnesota',
#  '584',
#  'Utah',
#  '24',
#  '31',
#  '21',
#  '21',
#  '24',
#  '38',
#  '33',
#  '16',
#  '102',
#  '106',
#  '58%',
#  '42%',
#  '+425',
#  '-550',
#  '+449',
#  '-533',
#  '+475',
#  '-560',
#  '+459',
#  '-620',
#  '+455',
#  '-560',
#  'Saturday, January 26, 2019',
#  '06:00 PM',
#  'H2H',
#  '|',
#  '501',
#  'San Antonio',
#  '502',
#  'New Orleans',
#  '-',
#  '-',
#  '-105',
#  '-125',
#  '-',
#  '-',
#  '-105',
#  '-125',
#  '-',
#  '-',
#  '-',
#  '-',
#  '08:00 PM',
#  'H2H',
#  '|',
#  '503',
#  'Indiana',
#  '504',
#  'Memphis',
#  '57%',
#  '43%',
#  '-145',
#  '+125',
#  '-188',
#  '+169',
#  '-175',
#  '+165',
#  '-175',
#  '+151',
#  '-180',
#  '+160',
#  '08:30 PM',
#  'H2H',
#  '|',
#  '505',
#  'Golden State',
#  '506',
#  'Boston',
#  '62%',
#  '38%',
#  '-135',
#  '+115',
#  '-152',
#  '+137',
#  '-150',
#  '+140',
#  '-144',
#  '+123',
#  '-159',
#  '+139',
#  '09:00 PM',
#  'H2H',
#  '|',
#  '507',
#  'Philadelphia',
#  '508',
#  'Denver',
#  '96%',
#  '4%',
#  '+245',
#  '-290',
#  '-',
#  '-',
#  '+285',
#  '-375',
#  '+330',
#  '-420',
#  '-',
#  '-',
#  '10:00 PM',
#  'H2H',
#  '|',
#  '509',
#  'Atlanta',
#  '510',
#  'Portland',
#  '33%',
#  '67%',
#  '+500',
#  '-700',
#  '+480',
#  '-575',
#  '+470',
#  '-555',
#  '+477',
#  '-650',
#  '+475',
#  '-600',
#  'Sunday, January 27, 2019',
#  '03:30 PM',
#  'H2H',
#  '|',
#  '511',
#  'Cleveland',
#  '512',
#  'Chicago',
#  '-',
#  '-',
#  '-',
#  '-',
#  '03:30 PM',
#  'H2H',
#  '|',
#  '513',
#  'Sacramento',
#  '514',
#  'L.A. Clippers',
#  '-',
#  '-',
#  '-',
#  '-',
#  '06:00 PM',
#  'H2H',
#  '|',
#  '515',
#  'Milwaukee',
#  '516',
#  'Oklahoma City',
#  '-',
#  '-',
#  '-',
#  '-',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '517',
#  'Toronto',
#  '518',
#  'Dallas',
#  '-',
#  '-',
#  '-',
#  '-',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '519',
#  'Orlando',
#  '520',
#  'Houston',
#  '-',
#  '-',
#  '-',
#  '-',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '521',
#  'Washington',
#  '522',
#  'San Antonio',
#  '-',
#  '-',
#  '-',
#  '-',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '523',
#  'Utah',
#  '524',
#  'Minnesota',
#  '-',
#  '-',
#  '-',
#  '-',
#  '07:30 PM',
#  'H2H',
#  '|',
#  '525',
#  'Miami',
#  '526',
#  'New York',
#  '-',
#  '-',
#  '-',
#  '-',
#  '09:30 PM',
#  'H2H',
#  '|',
#  '527',
#  'Phoenix',
#  '528',
#  'L.A. Lakers',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Monday, January 28, 2019',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '529',
#  'Golden State',
#  '530',
#  'Indiana',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
def populate(data, colnames, teamNames):
    game_id = 0
    team_count = 0
    odds_count = 0
    bookie_count = 0
    dt = data[0]
    
    for idx, elm in enumerate(data):
        
        # set data to first item in data list
        #if idx == 0: dt = elm

        
        # if element is a valid team name
        if elm in teamNames:
            colnames[1].append(dt)
            colnames[2].append(elm)
            colnames[0].append(game_id)
            team_count += 1
            
            # increment game_id once two teams are selected
            if team_count % 2 == 0:
                game_id += 1
                odds_count = 0
                bookie_count = 0
        
        # to account for overtime games, increment to the "wager" field
        # and then count backward to get total points
        if elm[-1] == "%" and data[idx-1][-1] == "%":
            colnames[3].append(data[idx-3])
            colnames[3].append(data[idx-2])
            
        if elm[-1] == "%":
            colnames[4].append(elm)

        #if idx >= 2:
        #    if data[idx-2][-1] == "%" and data[idx-1][-1] == "%":
                
        if elm[0] == '+' or elm[0] == '-':
            colnames[5+bookie_count].append(elm)
            odds_count += 1
            
            if odds_count % 2 == 0 and bookie_count < 4:
                bookie_count +=1
                
    return colnames

# %%
pop = populate(data,colnames,teamNames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-be70e146d1b3> in <module>()
# ----> 1 pop = populate(data,colnames,teamNames)
#
# NameError: name 'data' is not defined

# %%
dfout = pd.DataFrame(pop,
                    index= ['GameID', 'Date', 'Teams', 'Points', 'Wagers',
                              'Opener', 'Pinnacle', 'Fivedimes', 'Bookmaker', 'BetOnline']).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-25007d2fe5fc> in <module>()
# ----> 1 dfout = pd.DataFrame(pop,
#       2                     index= ['GameID', 'Date', 'Teams', 'Points', 'Wagers',
#       3                               'Opener', 'Pinnacle', 'Fivedimes', 'Bookmaker', 'BetOnline']).T
#
# NameError: name 'pop' is not defined

# %%
dfout
# Out:
#    GameID              Date          Teams Points Wagers Opener Pinnacle  \
# 0       0  Wed Dec 26, 2018        Phoenix    122    53%   +155     +185
# 1       0  Wed Dec 26, 2018        Orlando    120    47%   -175     -206
# 2       1  Wed Dec 26, 2018     Washington     95    52%   +175     +163
# 3       1  Wed Dec 26, 2018        Detroit    106    48%   -210     -181
# 4       2  Wed Dec 26, 2018        Indiana    129    54%   -345     -263
# 5       2  Wed Dec 26, 2018        Atlanta    121    46%   +285     +233
# 6       3  Wed Dec 26, 2018        Toronto    106    49%   -180     -122
# 7       3  Wed Dec 26, 2018          Miami    104    51%   +158     +111
# 8       4  Wed Dec 26, 2018      Charlotte    132    49%   +110     +101
# 9       4  Wed Dec 26, 2018       Brooklyn    134    51%   -130     -111
# 10      5  Wed Dec 26, 2018      Cleveland     87    48%   +425     +396
# 11      5  Wed Dec 26, 2018        Memphis     95    52%   -550     -464
# 12      6  Wed Dec 26, 2018      Minnesota    119    54%   -190     -171
# 13      6  Wed Dec 26, 2018        Chicago     94    46%   +165     +154
# 14      7  Wed Dec 26, 2018    New Orleans    119    48%   +115     +123
# 15      7  Wed Dec 26, 2018         Dallas    122    52%   -135     -136
# 16      8  Wed Dec 26, 2018         Denver    103    51%   +135     +154
# 17      8  Wed Dec 26, 2018    San Antonio    111    49%   -155     -171
# 18      9  Wed Dec 26, 2018     Sacramento    118    44%   +175     +177
# 19      9  Wed Dec 26, 2018  L.A. Clippers    127    56%   -210     -197
#
#    Fivedimes Bookmaker BetOnline
# 0       +190      +188      +180
# 1       -210      -225      -210
# 2       +165      +160      +163
# 3       -175      -185      -183
# 4       -265      -280      -265
# 5       +245      +230      +225
# 6       -125      -125      -130
# 7       +115      +105      +110
# 8       +102      -105      -102
# 9       -112      -115      -118
# 10      +420      +385      +420
# 11      -475      -501      -515
# 12      -170      -180      -175
# 13      +160      +155      +155
# 14      +120      +120      +115
# 15      -130      -140      -135
# 16      +160      +151      +157
# 17      -170      -175      -177
# 18      -125      +172      +175
# 19      -115      -199      -205

# %% [markdown]
# ## test concatenation of more bookies

# %% [markdown]
# ## think of how to utiilize the "click_arrow" path
# ## maybe we run the process "as is" above, then click the arrow,
# ## and basically run the process again and append the columns

# %%
## Set up chrome driver, open browser
path_to_chromedriver = "./web_scraping/chromedriver"
browser = webdriver.Chrome(executable_path=path_to_chromedriver)
browser.get(url);
time.sleep(3)  ## make sure the browswer loads before executing xpaths

## Use the xpaths to click the necessary browswer buttons
for xpath in xpaths:
    browser.find_element_by_xpath(xpath).click();
    time.sleep(3)  # Sleep in between
    
browser.find_element_by_xpath(click_arrow).click();
time.sleep(3)  # Sleep in between
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-430cd8a8e096> in <module>()
#       1 ## Set up chrome driver, open browser
#       2 path_to_chromedriver = "./web_scraping/chromedriver"
# ----> 3 browser = webdriver.Chrome(executable_path=path_to_chromedriver)
#       4 browser.get(url);
#       5 time.sleep(3)  ## make sure the browswer loads before executing xpaths
#
# NameError: name 'webdriver' is not defined

# %%
##
## PUT THIS BEFORE CLOSE BROWSET
##
click_arrow2 = 'html/body/div/div/div/div/section/div/div[3]/div[2]/div[3]/div[2]/div/div/div[2]'

# click again
browser.find_element_by_xpath(click_arrow2).click();
table_after2 = browser.find_element_by_id(object_id)

# %%
data_after2 = table_after2.text.split("\n")

# %%
data_after2[:45]
# Out:
# ['NBA Money Lines for Dec 26, 2018',
#  'Full Game',
#  '1st Half',
#  '2nd Half',
#  '1Q',
#  '2Q',
#  '3Q',
#  '4Q',
#  'Futures',
#  'Point Spreads',
#  'Money Lines',
#  'Totals',
#  'Spreads & Totals',
#  'Box Scores',
#  'Time',
#  '|',
#  'TV',
#  'Rot',
#  'Wed Dec 26, 2018',
#  'WAGERS',
#  'OPENER',
#  '07:00 PM',
#  'H2H',
#  '|',
#  '567',
#  'Phoenix',
#  '122',
#  '568',
#  'Orlando',
#  '120',
#  '53%',
#  '47%',
#  '+155',
#  '-175',
#  '+188',
#  '-225',
#  '+180',
#  '-210',
#  '+190',
#  '-220',
#  '+190',
#  '-210',
#  '07:00 PM',
#  'H2H',
#  '|']

# %%
# Containers
Opener3 = []
Justbet = []
Sportsbetting = []
Gtbets = []
Sportbet = []

colnames3 = [Opener3, Justbet, Sportsbetting, Gtbets, Sportbet]

# %%
# will need new populate function
def populate_after_click(data, colnames,teamNames):
    odds_count = 0
    bookie_count = 0
    team_count = 0
    
    for idx, elm in enumerate(data):
        
        # if element is a valid team name
        if elm in teamNames:
            team_count += 1
            
            # increment game_id once two teams are selected
            if team_count % 2 == 0:
                odds_count = 0
                bookie_count = 0
                
        if elm[0] == '+' or elm[0] == '-':
            colnames[bookie_count].append(elm)
            odds_count += 1
            
            if odds_count % 2 == 0 and bookie_count < 4:
                bookie_count +=1
                
    return colnames

# %%
pop_after2 = populate_after_click(data_after2,colnames3,teamNames)

# %%
dfout_after2 = pd.DataFrame(pop_after2,
                    index= ['Opener3','Justbet', 'Sportsbetting', 'Gtbets', 'Sportbet']).T

# %%
dfout_after2
# Out:
#    Opener3 Justbet Sportsbetting Gtbets Sportbet
# 0     +155    +188          +180   +190     +190
# 1     -175    -225          -210   -220     -210
# 2     +175    +160          +163   +165     +165
# 3     -210    -185          -183   -185     -175
# 4     -345    -280          -265   -275     -265
# 5     +285    +230          +225   +235     +245
# 6     -180    -125          -130   -145     -125
# 7     +158    +105          +110   +125     +115
# 8     +110    -105          -102   -103     +102
# 9     -130    -115          -118   -117     -112
# 10    +425    +385          +420   +400     +420
# 11    -550    -501          -515   -500     -475
# 12    -190    -180          -175   -175     -170
# 13    +165    +155          +155   +155     +160
# 14    +115    +120          +115   +110     +120
# 15    -135    -140          -135   -130     -130
# 16    +135    +151          +157   +155     +160
# 17    -155    -175          -177   -175     -170
# 18    +175    +172          +175   +170     -125
# 19    -210    -199          -205   -200     -115

# %% [markdown]
# ## Import File and Run

# %%
from scraping_nba_odds import nba_stats_info, scrape_nba_odds

# %%
url = list(nba_stats_info.keys())[0]

# %%
xstart = '/html/body/div[5]/div/div/section/div/div/div[2]/div[2]/table/tbody/tr['
xmid = ']/td['
xend = ']/div'
week = [1,2,3,4,5,6]
day = [1,2,3,4,5,6,7]
xpaths = [xstart + str(wk) + xmid + str(d) + xend for wk in week[::-1] for d in day[::-1]]

# %%
num_months = 4

# %%
dfout = scrape_nba_odds(url, xpaths, num_months)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Wed Jan 16, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Tue Jan 15, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Mon Jan 14, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Sun Jan 13, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Sat Jan 12, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Fri Jan 11, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Thu Jan 10, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Wed Jan 09, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Tue Jan 08, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Mon Jan 07, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping', dt, '........')
# Message: 'Scraping'
# Arguments: ('Sun Jan 06, 2019', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
# ...
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping %s.....', dt)
# Message: 'Scraping'
# Arguments: ('Thu Oct 04, 2018', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping %s.....', dt)
# Message: 'Scraping'
# Arguments: ('Wed Oct 03, 2018', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping %s.....', dt)
# Message: 'Scraping'
# Arguments: ('Tue Oct 02, 2018', '........')
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 992, in emit
#     msg = self.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 838, in format
#     return fmt.format(record)
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 575, in format
#     record.message = record.getMessage()
#   File "/home/richie10181/anaconda3/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/richie10181/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/richie10181/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3d42054c8166>", line 1, in <module>
#     dfout = scrape_nba_odds(url, xpaths, num_months)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 243, in scrape_nba_odds
#     pop = populate(data,colnames,teamNames)
#   File "/home/richie10181/anaconda3/RG_Ventures/SportsBetting/HistoricalData/Basketball/Odds/scraping_nba_odds.py", line 89, in populate
#     logging.info('Scraping %s.....', dt)
# Message: 'Scraping'
# Arguments: ('Mon Oct 01, 2018', '........')

# %% [markdown]
# ## why is it not selecting date?

# %%
dfout = dfout.drop(['Opener2','Opener3', 'Opener4','Opener5','Opener6','Opener7'],axis=1)

# %%
dfout.head()
# Out:
#   GameID              Date         Teams Points Wagers Opener Pinnacle  \
# 0      0  Sun Jan 13, 2019  Philadelphia    108    55%   -290     -415
# 1      0  Sun Jan 13, 2019      New York    105    45%   +230     +358
# 2      1  Sun Jan 13, 2019       Toronto    140    45%   -280     -202
# 3      1  Sun Jan 13, 2019    Washington    138    55%   +240     +181
# 4      2  Sun Jan 13, 2019     Milwaukee    133    63%   -650     -471
#
#   Fivedimes Bookmaker BetOnline  ...    Jazz Sportsinteraction Betcris   Sbr  \
# 0      -380      -450      -400  ...    -445              -390    -450  -400
# 1      +340      +351      +330  ...    +345              +300    +351  +317
# 2      -200      -225      -210  ...    -215              -230    -225  -225
# 3      +185      +188      +180  ...    +180              +190    +188  +188
# 4      -475      -525      -465  ...    -520              -430    -525  -500
#
#   Wagerweb Thegreek Bodog Matchbook Looselines Bet365
# 0     -400     -420  -450      -380       -445   -400
# 1     +320     +330  +325      +340       +345   +320
# 2     -195     -200  -210      -204       -215   -220
# 3     +170     +170  +175      +181       +180   +180
# 4     -525     -450  -550      -440       -520   -525
#
# [5 rows x 34 columns]

# %%
#save_df_jan_dec = dfout
# Out:
# 1382

# %%
dfout.to_csv('oct_jan_2018.csv', sep=',')

# %% [markdown]
# ## could we do this on the same site for different sports?
#
# ## next steps: turn odds into probabilities, add "outcome"/"winner" column
# ##                     create columns that would go into regression to find real vs consensus coef
